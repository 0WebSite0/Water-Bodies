# %%
from functools import partial
import os

import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from tensorflow import keras

# %%
import os
import numpy as np
from matplotlib import pyplot as plt
from tensorflow.keras.optimizers import Adam
#import tensorflow as tf
from datetime import datetime 
import cv2
from PIL import Image
#from keras import backend, optimizers

# %%
# force channels-first ordering for all loaded images
#backend.set_image_data_format('channels_last')  #The models are designed to use channels first

image_directory = "/kaggle/input/cleaned-dataset/Base_donnees/Images/"
mask_directory = "/kaggle/input/cleaned-dataset/Base_donnees/Masks/"

# %%
SIZE = 128
image_dataset = []  #Many ways to handle data, you can use pandas. Here, we are using a list format.  
mask_dataset = []  #Place holders to define add labels. We will add 0 to all parasitized images and 1 to uninfected.

# %%
images = os.listdir(image_directory)
for i, image_name in enumerate(images):    #Remember enumerate method adds a counter and returns the enumerate object
    if (image_name.split('.')[1] == 'jpg'):
        # print(image_directory+image_name)
        image = cv2.imread(image_directory+image_name, 1)
        image = Image.fromarray(image)
        image = image.resize((SIZE, SIZE))
        image_dataset.append(np.array(image))

# %%
#Iterate through all images in Uninfected folder, resize to 64 x 64
#Then save into the same numpy array 'dataset' but with label 1

masks = os.listdir(mask_directory)
for i, image_name in enumerate(masks):
    if (image_name.split('.')[1] == 'jpg'):
        image = cv2.imread(mask_directory+image_name, 0)
        image = Image.fromarray(image)
        image = image.resize((SIZE, SIZE))
        mask_dataset.append(np.array(image))

# %%
#Normalize images
image_dataset = np.array(image_dataset)/255.
#Do not normalize masks, just rescale to 0 to 1.
mask_dataset = np.expand_dims((np.array(mask_dataset)),3) /255.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(image_dataset, mask_dataset, test_size = 0.20, random_state = 0)

# %%
X_train.shape
# Out:
# (1770, 128, 128, 3)

# %%
#Sanity check, view few mages
import random
import numpy as np
image_number = random.randint(0, len(X_train))
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(np.reshape(X_train[image_number], (128, 128, 3)))
plt.subplot(122)
plt.imshow(np.reshape(y_train[image_number], (128, 128)), cmap='gray')
plt.show()

# %%
IMG_HEIGHT = X_train.shape[1]
IMG_WIDTH  = X_train.shape[2]
IMG_CHANNELS = X_train.shape[3]
num_labels = 1  #Binary
input_shape = (IMG_HEIGHT,IMG_WIDTH,IMG_CHANNELS)
batch_size = 8
#FOCAL LOSS AND DICE METRIC
#Focal loss helps focus more on tough to segment classes.
#from focal_loss import BinaryFocalLoss

# %%
# !pip install keras-unet-collection
# Out:
# Requirement already satisfied: keras-unet-collection in /opt/conda/lib/python3.10/site-packages (0.1.13)

# %%
from keras_unet_collection import models, losses

# %%
#Model 1: Unet with ImageNet trained VGG16 backbone
#help(models.att_unet_2d)

# %%
model_att_unet = models.att_unet_2d((128, 128, 3), filter_num=[64, 128, 256, 512, 1024], 
                           n_labels=num_labels, 
                           stack_num_down=2, stack_num_up=2, 
                           activation='ReLU', 
                           atten_activation='ReLU', attention='add', 
                           output_activation='Sigmoid', 
                           batch_norm=True, pool=False, unpool=False, 
                           backbone='VGG16', weights='imagenet', 
                           freeze_backbone=True, freeze_batch_norm=True, 
                           name='attunet')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras_unet_collection/_backbone_zoo.py:45: UserWarning:
#
# Backbone VGG16 does not use batch norm, but other layers received batch_norm=True
#   warnings.warn(param_mismatch);

# %%
model_att_unet.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate = 1e-4), 
              metrics=['accuracy', losses.dice_coef, losses.iou_seg])

# %%
#print(model_Unet.summary())

# %%
start1 = datetime.now() 
att_unet_history = model_att_unet.fit(X_train, y_train, 
                    verbose=1,
                    batch_size = batch_size,
                    validation_data=(X_test, y_test ), 
                    shuffle=False,
                    epochs=50)
stop1 = datetime.now()
# Out:
# Epoch 1/50
# 222/222 [==============================] - 47s 150ms/step - loss: 0.3016 - accuracy: 0.6908 - dice_coef: 0.6969 - iou_seg: 0.4564 - val_loss: 0.2212 - val_accuracy: 0.7278 - val_dice_coef: 0.7579 - val_iou_seg: 0.3859
# Epoch 2/50
# 222/222 [==============================] - 32s 145ms/step - loss: 0.2246 - accuracy: 0.7198 - dice_coef: 0.7774 - iou_seg: 0.3605 - val_loss: 0.2036 - val_accuracy: 0.7328 - val_dice_coef: 0.8073 - val_iou_seg: 0.3192
# Epoch 3/50
# 222/222 [==============================] - 30s 134ms/step - loss: 0.2000 - accuracy: 0.7276 - dice_coef: 0.8034 - iou_seg: 0.3255 - val_loss: 0.1970 - val_accuracy: 0.7340 - val_dice_coef: 0.8181 - val_iou_seg: 0.3038
# Epoch 4/50
# 222/222 [==============================] - 32s 145ms/step - loss: 0.1803 - accuracy: 0.7335 - dice_coef: 0.8237 - iou_seg: 0.2969 - val_loss: 0.2073 - val_accuracy: 0.7324 - val_dice_coef: 0.8274 - val_iou_seg: 0.2903
# Epoch 5/50
# 222/222 [==============================] - 32s 145ms/step - loss: 0.1638 - accuracy: 0.7382 - dice_coef: 0.8408 - iou_seg: 0.2721 - val_loss: 0.2180 - val_accuracy: 0.7323 - val_dice_coef: 0.8304 - val_iou_seg: 0.2855
# Epoch 6/50
# 222/222 [==============================] - 32s 145ms/step - loss: 0.1499 - accuracy: 0.7419 - dice_coef: 0.8553 - iou_seg: 0.2506 - val_loss: 0.2285 - val_accuracy: 0.7309 - val_dice_coef: 0.8244 - val_iou_seg: 0.2939
# Epoch 7/50
# 222/222 [==============================] - 30s 134ms/step - loss: 0.1419 - accuracy: 0.7436 - dice_coef: 0.8635 - iou_seg: 0.2381 - val_loss: 0.2168 - val_accuracy: 0.7323 - val_dice_coef: 0.8294 - val_iou_seg: 0.2869
# Epoch 8/50
# 222/222 [==============================] - 30s 134ms/step - loss: 0.1367 - accuracy: 0.7448 - dice_coef: 0.8691 - iou_seg: 0.2294 - val_loss: 0.2327 - val_accuracy: 0.7320 - val_dice_coef: 0.8294 - val_iou_seg: 0.2867
# Epoch 9/50
# 222/222 [==============================] - 32s 145ms/step - loss: 0.1291 - accuracy: 0.7465 - dice_coef: 0.8767 - iou_seg: 0.2178 - val_loss: 0.2600 - val_accuracy: 0.7315 - val_dice_coef: 0.8336 - val_iou_seg: 0.2805
# Epoch 10/50
# 222/222 [==============================] - 32s 145ms/step - loss: 0.1227 - accuracy: 0.7478 - dice_coef: 0.8830 - iou_seg: 0.2077 - val_loss: 0.2701 - val_accuracy: 0.7253 - val_dice_coef: 0.8340 - val_iou_seg: 0.2803
# Epoch 11/50
# 222/222 [==============================] - 32s 145ms/step - loss: 0.1181 - accuracy: 0.7485 - dice_coef: 0.8878 - iou_seg: 0.2001 - val_loss: 0.2518 - val_accuracy: 0.7328 - val_dice_coef: 0.8404 - val_iou_seg: 0.2708
# Epoch 12/50
# 222/222 [==============================] - 30s 135ms/step - loss: 0.1140 - accuracy: 0.7490 - dice_coef: 0.8912 - iou_seg: 0.1947 - val_loss: 0.2223 - val_accuracy: 0.7318 - val_dice_coef: 0.8418 - val_iou_seg: 0.2689
# Epoch 13/50
# 222/222 [==============================] - 30s 135ms/step - loss: 0.1092 - accuracy: 0.7499 - dice_coef: 0.8967 - iou_seg: 0.1860 - val_loss: 0.2265 - val_accuracy: 0.7333 - val_dice_coef: 0.8433 - val_iou_seg: 0.2662
# Epoch 14/50
# 222/222 [==============================] - 30s 135ms/step - loss: 0.1070 - accuracy: 0.7501 - dice_coef: 0.8986 - iou_seg: 0.1828 - val_loss: 0.2183 - val_accuracy: 0.7358 - val_dice_coef: 0.8451 - val_iou_seg: 0.2641
# Epoch 15/50
# 222/222 [==============================] - 32s 145ms/step - loss: 0.1046 - accuracy: 0.7506 - dice_coef: 0.9009 - iou_seg: 0.1789 - val_loss: 0.2438 - val_accuracy: 0.7349 - val_dice_coef: 0.8539 - val_iou_seg: 0.2507
# Epoch 16/50
# 222/222 [==============================] - 30s 135ms/step - loss: 0.1012 - accuracy: 0.7509 - dice_coef: 0.9043 - iou_seg: 0.1734 - val_loss: 0.2379 - val_accuracy: 0.7351 - val_dice_coef: 0.8522 - val_iou_seg: 0.2535
# Epoch 17/50
# 222/222 [==============================] - 32s 145ms/step - loss: 0.0959 - accuracy: 0.7518 - dice_coef: 0.9095 - iou_seg: 0.1649 - val_loss: 0.2189 - val_accuracy: 0.7357 - val_dice_coef: 0.8576 - val_iou_seg: 0.2456
# Epoch 18/50
# 222/222 [==============================] - 32s 145ms/step - loss: 0.0935 - accuracy: 0.7520 - dice_coef: 0.9118 - iou_seg: 0.1612 - val_loss: 0.2230 - val_accuracy: 0.7368 - val_dice_coef: 0.8596 - val_iou_seg: 0.2423
# Epoch 19/50
# 222/222 [==============================] - 30s 135ms/step - loss: 0.0909 - accuracy: 0.7523 - dice_coef: 0.9142 - iou_seg: 0.1570 - val_loss: 0.2218 - val_accuracy: 0.7365 - val_dice_coef: 0.8597 - val_iou_seg: 0.2424
# Epoch 20/50
# 222/222 [==============================] - 32s 145ms/step - loss: 0.0905 - accuracy: 0.7522 - dice_coef: 0.9147 - iou_seg: 0.1562 - val_loss: 0.2274 - val_accuracy: 0.7373 - val_dice_coef: 0.8527 - val_iou_seg: 0.2527
# Epoch 21/50
# 222/222 [==============================] - 32s 145ms/step - loss: 0.0930 - accuracy: 0.7516 - dice_coef: 0.9125 - iou_seg: 0.1598 - val_loss: 0.2031 - val_accuracy: 0.7362 - val_dice_coef: 0.8559 - val_iou_seg: 0.2482
# Epoch 22/50
# 222/222 [==============================] - 30s 134ms/step - loss: 0.0893 - accuracy: 0.7523 - dice_coef: 0.9160 - iou_seg: 0.1541 - val_loss: 0.2143 - val_accuracy: 0.7380 - val_dice_coef: 0.8603 - val_iou_seg: 0.2412
# Epoch 23/50
# 222/222 [==============================] - 32s 145ms/step - loss: 0.0846 - accuracy: 0.7529 - dice_coef: 0.9204 - iou_seg: 0.1466 - val_loss: 0.2202 - val_accuracy: 0.7374 - val_dice_coef: 0.8656 - val_iou_seg: 0.2332
# Epoch 24/50
# 222/222 [==============================] - 32s 145ms/step - loss: 0.0823 - accuracy: 0.7532 - dice_coef: 0.9227 - iou_seg: 0.1427 - val_loss: 0.2191 - val_accuracy: 0.7365 - val_dice_coef: 0.8641 - val_iou_seg: 0.2360
# Epoch 25/50
# 222/222 [==============================] - 32s 145ms/step - loss: 0.0837 - accuracy: 0.7529 - dice_coef: 0.9215 - iou_seg: 0.1448 - val_loss: 0.2513 - val_accuracy: 0.7300 - val_dice_coef: 0.8516 - val_iou_seg: 0.2548
# Epoch 26/50
# 222/222 [==============================] - 32s 145ms/step - loss: 0.0829 - accuracy: 0.7530 - dice_coef: 0.9221 - iou_seg: 0.1437 - val_loss: 0.2300 - val_accuracy: 0.7377 - val_dice_coef: 0.8628 - val_iou_seg: 0.2373
# Epoch 27/50
# 222/222 [==============================] - 32s 145ms/step - loss: 0.0793 - accuracy: 0.7535 - dice_coef: 0.9256 - iou_seg: 0.1377 - val_loss: 0.2163 - val_accuracy: 0.7372 - val_dice_coef: 0.8644 - val_iou_seg: 0.2353
# Epoch 28/50
# 222/222 [==============================] - 32s 145ms/step - loss: 0.0766 - accuracy: 0.7538 - dice_coef: 0.9282 - iou_seg: 0.1333 - val_loss: 0.2188 - val_accuracy: 0.7350 - val_dice_coef: 0.8623 - val_iou_seg: 0.2387
# Epoch 29/50
# 222/222 [==============================] - 32s 145ms/step - loss: 0.0753 - accuracy: 0.7539 - dice_coef: 0.9294 - iou_seg: 0.1311 - val_loss: 0.2252 - val_accuracy: 0.7358 - val_dice_coef: 0.8633 - val_iou_seg: 0.2367
# Epoch 30/50
# 222/222 [==============================] - 32s 145ms/step - loss: 0.0749 - accuracy: 0.7539 - dice_coef: 0.9299 - iou_seg: 0.1303 - val_loss: 0.2108 - val_accuracy: 0.7371 - val_dice_coef: 0.8645 - val_iou_seg: 0.2351
# Epoch 31/50
# 222/222 [==============================] - 30s 135ms/step - loss: 0.0740 - accuracy: 0.7540 - dice_coef: 0.9309 - iou_seg: 0.1286 - val_loss: 0.2442 - val_accuracy: 0.7353 - val_dice_coef: 0.8662 - val_iou_seg: 0.2324
# Epoch 32/50
# 222/222 [==============================] - 32s 145ms/step - loss: 0.0750 - accuracy: 0.7539 - dice_coef: 0.9301 - iou_seg: 0.1299 - val_loss: 0.2498 - val_accuracy: 0.7325 - val_dice_coef: 0.8633 - val_iou_seg: 0.2369
# Epoch 33/50
# 222/222 [==============================] - 30s 134ms/step - loss: 0.0745 - accuracy: 0.7539 - dice_coef: 0.9305 - iou_seg: 0.1292 - val_loss: 0.2950 - val_accuracy: 0.7222 - val_dice_coef: 0.8382 - val_iou_seg: 0.2746
# Epoch 34/50
# 222/222 [==============================] - 32s 145ms/step - loss: 0.0731 - accuracy: 0.7541 - dice_coef: 0.9318 - iou_seg: 0.1270 - val_loss: 0.2580 - val_accuracy: 0.7281 - val_dice_coef: 0.8532 - val_iou_seg: 0.2521
# Epoch 35/50
# 222/222 [==============================] - 32s 145ms/step - loss: 0.0720 - accuracy: 0.7542 - dice_coef: 0.9328 - iou_seg: 0.1252 - val_loss: 0.2366 - val_accuracy: 0.7313 - val_dice_coef: 0.8543 - val_iou_seg: 0.2509
# Epoch 36/50
# 222/222 [==============================] - 30s 135ms/step - loss: 0.0755 - accuracy: 0.7534 - dice_coef: 0.9297 - iou_seg: 0.1307 - val_loss: 0.3263 - val_accuracy: 0.7199 - val_dice_coef: 0.8321 - val_iou_seg: 0.2828
# Epoch 37/50
# 222/222 [==============================] - 30s 134ms/step - loss: 0.0738 - accuracy: 0.7538 - dice_coef: 0.9312 - iou_seg: 0.1280 - val_loss: 0.2761 - val_accuracy: 0.7319 - val_dice_coef: 0.8538 - val_iou_seg: 0.2511
# Epoch 38/50
# 222/222 [==============================] - 30s 134ms/step - loss: 0.0795 - accuracy: 0.7528 - dice_coef: 0.9260 - iou_seg: 0.1370 - val_loss: 0.2198 - val_accuracy: 0.7378 - val_dice_coef: 0.8612 - val_iou_seg: 0.2401
# Epoch 39/50
# 222/222 [==============================] - 32s 145ms/step - loss: 0.0693 - accuracy: 0.7544 - dice_coef: 0.9353 - iou_seg: 0.1209 - val_loss: 0.2343 - val_accuracy: 0.7374 - val_dice_coef: 0.8684 - val_iou_seg: 0.2290
# Epoch 40/50
# 222/222 [==============================] - 32s 145ms/step - loss: 0.0669 - accuracy: 0.7547 - dice_coef: 0.9379 - iou_seg: 0.1164 - val_loss: 0.2333 - val_accuracy: 0.7355 - val_dice_coef: 0.8642 - val_iou_seg: 0.2356
# Epoch 41/50
# 222/222 [==============================] - 30s 134ms/step - loss: 0.0660 - accuracy: 0.7548 - dice_coef: 0.9388 - iou_seg: 0.1148 - val_loss: 0.2269 - val_accuracy: 0.7371 - val_dice_coef: 0.8653 - val_iou_seg: 0.2337
# Epoch 42/50
# 222/222 [==============================] - 30s 134ms/step - loss: 0.0650 - accuracy: 0.7549 - dice_coef: 0.9397 - iou_seg: 0.1132 - val_loss: 0.2333 - val_accuracy: 0.7346 - val_dice_coef: 0.8620 - val_iou_seg: 0.2391
# Epoch 43/50
# 222/222 [==============================] - 30s 134ms/step - loss: 0.0649 - accuracy: 0.7549 - dice_coef: 0.9399 - iou_seg: 0.1129 - val_loss: 0.2299 - val_accuracy: 0.7344 - val_dice_coef: 0.8600 - val_iou_seg: 0.2423
# Epoch 44/50
# 222/222 [==============================] - 30s 134ms/step - loss: 0.0647 - accuracy: 0.7549 - dice_coef: 0.9401 - iou_seg: 0.1126 - val_loss: 0.2478 - val_accuracy: 0.7314 - val_dice_coef: 0.8511 - val_iou_seg: 0.2556
# Epoch 45/50
# 222/222 [==============================] - 32s 145ms/step - loss: 0.0646 - accuracy: 0.7549 - dice_coef: 0.9401 - iou_seg: 0.1125 - val_loss: 0.2630 - val_accuracy: 0.7312 - val_dice_coef: 0.8565 - val_iou_seg: 0.2475
# Epoch 46/50
# 222/222 [==============================] - 32s 145ms/step - loss: 0.0649 - accuracy: 0.7549 - dice_coef: 0.9399 - iou_seg: 0.1129 - val_loss: 0.2403 - val_accuracy: 0.7378 - val_dice_coef: 0.8636 - val_iou_seg: 0.2364
# Epoch 47/50
# 222/222 [==============================] - 30s 134ms/step - loss: 0.0646 - accuracy: 0.7549 - dice_coef: 0.9401 - iou_seg: 0.1125 - val_loss: 0.2305 - val_accuracy: 0.7365 - val_dice_coef: 0.8647 - val_iou_seg: 0.2347
# Epoch 48/50
# 222/222 [==============================] - 32s 145ms/step - loss: 0.0646 - accuracy: 0.7548 - dice_coef: 0.9401 - iou_seg: 0.1124 - val_loss: 0.2624 - val_accuracy: 0.7319 - val_dice_coef: 0.8564 - val_iou_seg: 0.2469
# Epoch 49/50
# 222/222 [==============================] - 32s 145ms/step - loss: 0.0643 - accuracy: 0.7549 - dice_coef: 0.9405 - iou_seg: 0.1118 - val_loss: 0.2528 - val_accuracy: 0.7370 - val_dice_coef: 0.8695 - val_iou_seg: 0.2270
# Epoch 50/50
# 222/222 [==============================] - 32s 145ms/step - loss: 0.0618 - accuracy: 0.7552 - dice_coef: 0.9429 - iou_seg: 0.1076 - val_loss: 0.2496 - val_accuracy: 0.7373 - val_dice_coef: 0.8690 - val_iou_seg: 0.2278

# %%
#Execution time of the model 
execution_time_att_unet = stop1-start1
print("att_unet execution time is: ", execution_time_att_unet)
# Out:
# att_unet execution time is:  0:26:20.138682

# %%
model_att_unet.save('attentionUnet.hdf5')

# %%
# convert the history.history dict to a pandas DataFrame and save as csv for
# future plotting
import pandas as pd    
att_unet_history_df = pd.DataFrame(att_unet_history.history) 

with open('att_unet_history_df.csv', mode='w') as f:
    att_unet_history_df.to_csv(f)

# %%
#Check history plots, one model at a time
history = att_unet_history

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.ylim(0, 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['dice_coef']
#acc = history.history['accuracy']
val_acc = history.history['val_dice_coef']
#val_acc = history.history['val_accuracy']

plt.ylim(0, 1)
plt.plot(epochs, acc, 'y', label='Training Dice')
plt.plot(epochs, val_acc, 'r', label='Validation Dice')
plt.title('Training and validation Dice')
plt.xlabel('Epochs')
plt.ylabel('Dice')
plt.legend()
plt.show()

# %%
model = model_att_unet

# %%
import random
test_img_number = random.randint(0, X_test.shape[0]-1)  #Test with 119

# %%
test_img = X_test[test_img_number]
ground_truth=y_test[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
prediction = (model.predict(test_img_input)[0,:,:,0] > 0.5).astype(np.uint8)
# Out:
# 1/1 [==============================] - 1s 677ms/step

# %%
plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img, cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0], cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(prediction, cmap='gray')

plt.show()

# %%
## Choose the number of examples to display
num_examples = 3

test_img = X_test[test_img_number]
ground_truth=y_test[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
prediction1 = (model.predict(test_img_input)[0,:,:,0] > 0.5).astype(np.uint8)


# Randomly select some indices for display
example_indices = [1,5,4]

# Display the selected examples
plt.figure(figsize=(15, 5 * num_examples))

for i, example_index in enumerate(example_indices, 1):
    test_img = X_test[example_index]
    test_img_input=np.expand_dims(test_img, 0)
    prediction1 = (model.predict(test_img_input)[0,:,:,0] > 0.5).astype(np.uint8)
    plt.subplot(num_examples, 3, 3 * i - 2)
    plt.imshow(X_test[example_index])
    plt.title(f"Image {example_index}")
    plt.axis('off')
    
    plt.subplot(num_examples, 3, 3 * i - 1)
    plt.imshow(y_test[example_index], cmap='gray')
    plt.title(f"Mask {example_index}")
    plt.axis('off')

    plt.subplot(num_examples, 3, 3 * i)
    plt.imshow(prediction1, cmap='gray')
    plt.title(f"Prediction {example_index}")
    plt.axis('off')

    
plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step

# %%
#IoU for a single image
from tensorflow.keras.metrics import MeanIoU
n_classes = 2
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(ground_truth[:,:,0], prediction)
print(" IoU =", IOU_keras.result().numpy())
# Out:
#  IoU = 0.72589207

# %%
import pandas as pd

IoU_values = []
for img in range(0, X_test.shape[0]):
    temp_img = X_test[img]
    ground_truth=y_test[img]
    temp_img_input=np.expand_dims(temp_img, 0)
    prediction = (model.predict(temp_img_input)[0,:,:,0] > 0.5).astype(np.uint8)
    
    IoU = MeanIoU(num_classes=n_classes)
    IoU.update_state(ground_truth[:,:,0], prediction)
    IoU = IoU.result().numpy()
    IoU_values.append(IoU)

    #print(IoU)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step

# %%
df = pd.DataFrame(IoU_values, columns=["IoU"])
df = df[df.IoU != 1.0]    
mean_IoU = df.mean().values
print("Mean IoU is: ", mean_IoU)
# Out:
# Mean IoU is:  [0.6977322]
