# %%
from functools import partial
import os

import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from tensorflow import keras

# %%
import os
import numpy as np
from matplotlib import pyplot as plt
from tensorflow.keras.optimizers import Adam
#import tensorflow as tf
from datetime import datetime 
import cv2
from PIL import Image
#from keras import backend, optimizers

# %%
# force channels-first ordering for all loaded images
#backend.set_image_data_format('channels_last')  #The models are designed to use channels first

image_directory = "/kaggle/input/cleaned-dataset/Base_donnees/Images/"
mask_directory = "/kaggle/input/cleaned-dataset/Base_donnees/Masks/"

# %%
SIZE = 128
image_dataset = []  #Many ways to handle data, you can use pandas. Here, we are using a list format.  
mask_dataset = []  #Place holders to define add labels. We will add 0 to all parasitized images and 1 to uninfected.

# %%
images = os.listdir(image_directory)
for i, image_name in enumerate(images):    #Remember enumerate method adds a counter and returns the enumerate object
    if (image_name.split('.')[1] == 'jpg'):
        # print(image_directory+image_name)
        image = cv2.imread(image_directory+image_name, 1)
        image = Image.fromarray(image)
        image = image.resize((SIZE, SIZE))
        image_dataset.append(np.array(image))

# %%
#Iterate through all images in Uninfected folder, resize to 64 x 64
#Then save into the same numpy array 'dataset' but with label 1

masks = os.listdir(mask_directory)
for i, image_name in enumerate(masks):
    if (image_name.split('.')[1] == 'jpg'):
        image = cv2.imread(mask_directory+image_name, 0)
        image = Image.fromarray(image)
        image = image.resize((SIZE, SIZE))
        mask_dataset.append(np.array(image))

# %%
#Normalize images
image_dataset = np.array(image_dataset)/255.
#Do not normalize masks, just rescale to 0 to 1.
mask_dataset = np.expand_dims((np.array(mask_dataset)),3) /255.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(image_dataset, mask_dataset, test_size = 0.20, random_state = 0)

# %%
X_train.shape
# Out:
# (1770, 128, 128, 3)

# %%
#Sanity check, view few mages
import random
import numpy as np
image_number = random.randint(0, len(X_train))
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.imshow(np.reshape(X_train[image_number], (128, 128, 3)))
plt.subplot(122)
plt.imshow(np.reshape(y_train[image_number], (128, 128)), cmap='gray')
plt.show()

# %%
IMG_HEIGHT = X_train.shape[1]
IMG_WIDTH  = X_train.shape[2]
IMG_CHANNELS = X_train.shape[3]
num_labels = 1  #Binary
input_shape = (IMG_HEIGHT,IMG_WIDTH,IMG_CHANNELS)
batch_size = 4
#FOCAL LOSS AND DICE METRIC
#Focal loss helps focus more on tough to segment classes.
#from focal_loss import BinaryFocalLoss

# %%
# !pip install keras-unet-collection
# Out:
# Requirement already satisfied: keras-unet-collection in /opt/conda/lib/python3.10/site-packages (0.1.13)

# %%
from keras_unet_collection import models, losses

# %%
#Model 1: Unet with ImageNet trained VGG16 backbone
#help(models.att_unet_2d)

# %%
model_att_unet = models.att_unet_2d((128, 128, 3), filter_num=[64, 128, 256, 512, 1024], 
                           n_labels=num_labels, 
                           stack_num_down=2, stack_num_up=2, 
                           activation='ReLU', 
                           atten_activation='ReLU', attention='add', 
                           output_activation='Sigmoid', 
                           batch_norm=True, pool=False, unpool=False, 
                           backbone='VGG16', weights='imagenet', 
                           freeze_backbone=True, freeze_batch_norm=True, 
                           name='attunet')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras_unet_collection/_backbone_zoo.py:45: UserWarning:
#
# Backbone VGG16 does not use batch norm, but other layers received batch_norm=True
#   warnings.warn(param_mismatch);

# %%
model_att_unet.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate = 1e-4), 
              metrics=['accuracy', losses.dice_coef, losses.iou_seg])

# %%
#print(model_Unet.summary())

# %%
start1 = datetime.now() 
att_unet_history = model_att_unet.fit(X_train, y_train, 
                    verbose=1,
                    batch_size = batch_size,
                    validation_data=(X_test, y_test ), 
                    shuffle=False,
                    epochs=50)
stop1 = datetime.now()
# Out:
# Epoch 1/50
# 443/443 [==============================] - 50s 85ms/step - loss: 0.2972 - accuracy: 0.6965 - dice_coef: 0.7009 - iou_seg: 0.4501 - val_loss: 0.2187 - val_accuracy: 0.7278 - val_dice_coef: 0.7736 - val_iou_seg: 0.3622
# Epoch 2/50
# 443/443 [==============================] - 38s 86ms/step - loss: 0.2259 - accuracy: 0.7199 - dice_coef: 0.7679 - iou_seg: 0.3695 - val_loss: 0.2387 - val_accuracy: 0.7252 - val_dice_coef: 0.7898 - val_iou_seg: 0.3409
# Epoch 3/50
# 443/443 [==============================] - 38s 85ms/step - loss: 0.2013 - accuracy: 0.7273 - dice_coef: 0.7934 - iou_seg: 0.3359 - val_loss: 0.2893 - val_accuracy: 0.7175 - val_dice_coef: 0.7870 - val_iou_seg: 0.3445
# Epoch 4/50
# 443/443 [==============================] - 36s 81ms/step - loss: 0.1819 - accuracy: 0.7333 - dice_coef: 0.8133 - iou_seg: 0.3085 - val_loss: 0.3782 - val_accuracy: 0.7027 - val_dice_coef: 0.7733 - val_iou_seg: 0.3623
# Epoch 5/50
# 443/443 [==============================] - 38s 85ms/step - loss: 0.1676 - accuracy: 0.7374 - dice_coef: 0.8291 - iou_seg: 0.2864 - val_loss: 0.4318 - val_accuracy: 0.6944 - val_dice_coef: 0.7705 - val_iou_seg: 0.3658
# Epoch 6/50
# 443/443 [==============================] - 38s 85ms/step - loss: 0.1554 - accuracy: 0.7406 - dice_coef: 0.8412 - iou_seg: 0.2688 - val_loss: 0.2156 - val_accuracy: 0.7317 - val_dice_coef: 0.8202 - val_iou_seg: 0.2986
# Epoch 7/50
# 443/443 [==============================] - 38s 85ms/step - loss: 0.1459 - accuracy: 0.7431 - dice_coef: 0.8522 - iou_seg: 0.2527 - val_loss: 0.3138 - val_accuracy: 0.7102 - val_dice_coef: 0.7951 - val_iou_seg: 0.3329
# Epoch 8/50
# 443/443 [==============================] - 36s 81ms/step - loss: 0.1376 - accuracy: 0.7448 - dice_coef: 0.8610 - iou_seg: 0.2396 - val_loss: 0.2009 - val_accuracy: 0.7364 - val_dice_coef: 0.8359 - val_iou_seg: 0.2756
# Epoch 9/50
# 443/443 [==============================] - 36s 81ms/step - loss: 0.1360 - accuracy: 0.7450 - dice_coef: 0.8641 - iou_seg: 0.2349 - val_loss: 0.2007 - val_accuracy: 0.7357 - val_dice_coef: 0.8310 - val_iou_seg: 0.2819
# Epoch 10/50
# 443/443 [==============================] - 36s 81ms/step - loss: 0.1262 - accuracy: 0.7472 - dice_coef: 0.8740 - iou_seg: 0.2200 - val_loss: 0.2381 - val_accuracy: 0.7278 - val_dice_coef: 0.8279 - val_iou_seg: 0.2872
# Epoch 11/50
# 443/443 [==============================] - 38s 85ms/step - loss: 0.1214 - accuracy: 0.7480 - dice_coef: 0.8793 - iou_seg: 0.2116 - val_loss: 0.2427 - val_accuracy: 0.7291 - val_dice_coef: 0.8300 - val_iou_seg: 0.2837
# Epoch 12/50
# 443/443 [==============================] - 38s 85ms/step - loss: 0.1185 - accuracy: 0.7484 - dice_coef: 0.8820 - iou_seg: 0.2075 - val_loss: 0.2280 - val_accuracy: 0.7349 - val_dice_coef: 0.8341 - val_iou_seg: 0.2773
# Epoch 13/50
# 443/443 [==============================] - 38s 85ms/step - loss: 0.1145 - accuracy: 0.7490 - dice_coef: 0.8867 - iou_seg: 0.2002 - val_loss: 0.2429 - val_accuracy: 0.7342 - val_dice_coef: 0.8384 - val_iou_seg: 0.2706
# Epoch 14/50
# 443/443 [==============================] - 38s 85ms/step - loss: 0.1112 - accuracy: 0.7496 - dice_coef: 0.8904 - iou_seg: 0.1944 - val_loss: 0.2452 - val_accuracy: 0.7346 - val_dice_coef: 0.8358 - val_iou_seg: 0.2743
# Epoch 15/50
# 443/443 [==============================] - 38s 85ms/step - loss: 0.1085 - accuracy: 0.7498 - dice_coef: 0.8933 - iou_seg: 0.1898 - val_loss: 0.2434 - val_accuracy: 0.7347 - val_dice_coef: 0.8408 - val_iou_seg: 0.2674
# Epoch 16/50
# 443/443 [==============================] - 38s 85ms/step - loss: 0.1051 - accuracy: 0.7503 - dice_coef: 0.8961 - iou_seg: 0.1854 - val_loss: 0.2385 - val_accuracy: 0.7339 - val_dice_coef: 0.8342 - val_iou_seg: 0.2763
# Epoch 17/50
# 443/443 [==============================] - 38s 85ms/step - loss: 0.1019 - accuracy: 0.7508 - dice_coef: 0.8998 - iou_seg: 0.1794 - val_loss: 0.2204 - val_accuracy: 0.7369 - val_dice_coef: 0.8439 - val_iou_seg: 0.2628
# Epoch 18/50
# 443/443 [==============================] - 38s 85ms/step - loss: 0.1019 - accuracy: 0.7507 - dice_coef: 0.9002 - iou_seg: 0.1789 - val_loss: 0.2610 - val_accuracy: 0.7340 - val_dice_coef: 0.8320 - val_iou_seg: 0.2793
# Epoch 19/50
# 443/443 [==============================] - 38s 85ms/step - loss: 0.0985 - accuracy: 0.7511 - dice_coef: 0.9031 - iou_seg: 0.1742 - val_loss: 0.2411 - val_accuracy: 0.7364 - val_dice_coef: 0.8442 - val_iou_seg: 0.2624
# Epoch 20/50
# 443/443 [==============================] - 38s 85ms/step - loss: 0.0974 - accuracy: 0.7513 - dice_coef: 0.9042 - iou_seg: 0.1723 - val_loss: 0.2672 - val_accuracy: 0.7359 - val_dice_coef: 0.8451 - val_iou_seg: 0.2607
# Epoch 21/50
# 443/443 [==============================] - 38s 85ms/step - loss: 0.0929 - accuracy: 0.7519 - dice_coef: 0.9087 - iou_seg: 0.1650 - val_loss: 0.3298 - val_accuracy: 0.7304 - val_dice_coef: 0.8105 - val_iou_seg: 0.3098
# Epoch 22/50
# 443/443 [==============================] - 36s 81ms/step - loss: 0.0904 - accuracy: 0.7522 - dice_coef: 0.9113 - iou_seg: 0.1608 - val_loss: 0.2411 - val_accuracy: 0.7374 - val_dice_coef: 0.8505 - val_iou_seg: 0.2532
# Epoch 23/50
# 443/443 [==============================] - 38s 85ms/step - loss: 0.0878 - accuracy: 0.7526 - dice_coef: 0.9141 - iou_seg: 0.1562 - val_loss: 0.2416 - val_accuracy: 0.7364 - val_dice_coef: 0.8487 - val_iou_seg: 0.2564
# Epoch 24/50
# 443/443 [==============================] - 36s 81ms/step - loss: 0.0877 - accuracy: 0.7526 - dice_coef: 0.9144 - iou_seg: 0.1558 - val_loss: 0.2267 - val_accuracy: 0.7349 - val_dice_coef: 0.8493 - val_iou_seg: 0.2551
# Epoch 25/50
# 443/443 [==============================] - 38s 85ms/step - loss: 0.0853 - accuracy: 0.7528 - dice_coef: 0.9166 - iou_seg: 0.1521 - val_loss: 0.2496 - val_accuracy: 0.7361 - val_dice_coef: 0.8499 - val_iou_seg: 0.2542
# Epoch 26/50
# 443/443 [==============================] - 38s 85ms/step - loss: 0.0826 - accuracy: 0.7532 - dice_coef: 0.9193 - iou_seg: 0.1475 - val_loss: 0.2235 - val_accuracy: 0.7367 - val_dice_coef: 0.8554 - val_iou_seg: 0.2472
# Epoch 27/50
# 443/443 [==============================] - 38s 85ms/step - loss: 0.0822 - accuracy: 0.7532 - dice_coef: 0.9197 - iou_seg: 0.1468 - val_loss: 0.2181 - val_accuracy: 0.7367 - val_dice_coef: 0.8557 - val_iou_seg: 0.2467
# Epoch 28/50
# 443/443 [==============================] - 36s 82ms/step - loss: 0.0821 - accuracy: 0.7531 - dice_coef: 0.9200 - iou_seg: 0.1464 - val_loss: 0.2056 - val_accuracy: 0.7377 - val_dice_coef: 0.8556 - val_iou_seg: 0.2467
# Epoch 29/50
# 443/443 [==============================] - 38s 86ms/step - loss: 0.0813 - accuracy: 0.7532 - dice_coef: 0.9207 - iou_seg: 0.1451 - val_loss: 0.2158 - val_accuracy: 0.7362 - val_dice_coef: 0.8496 - val_iou_seg: 0.2561
# Epoch 30/50
# 443/443 [==============================] - 38s 85ms/step - loss: 0.0806 - accuracy: 0.7532 - dice_coef: 0.9214 - iou_seg: 0.1440 - val_loss: 0.2181 - val_accuracy: 0.7389 - val_dice_coef: 0.8586 - val_iou_seg: 0.2420
# Epoch 31/50
# 443/443 [==============================] - 36s 81ms/step - loss: 0.0802 - accuracy: 0.7533 - dice_coef: 0.9219 - iou_seg: 0.1432 - val_loss: 0.2037 - val_accuracy: 0.7389 - val_dice_coef: 0.8607 - val_iou_seg: 0.2395
# Epoch 32/50
# 443/443 [==============================] - 36s 81ms/step - loss: 0.0775 - accuracy: 0.7537 - dice_coef: 0.9243 - iou_seg: 0.1391 - val_loss: 0.2274 - val_accuracy: 0.7383 - val_dice_coef: 0.8604 - val_iou_seg: 0.2395
# Epoch 33/50
# 443/443 [==============================] - 36s 81ms/step - loss: 0.0758 - accuracy: 0.7539 - dice_coef: 0.9263 - iou_seg: 0.1357 - val_loss: 0.2471 - val_accuracy: 0.7357 - val_dice_coef: 0.8595 - val_iou_seg: 0.2409
# Epoch 34/50
# 443/443 [==============================] - 38s 85ms/step - loss: 0.0749 - accuracy: 0.7539 - dice_coef: 0.9271 - iou_seg: 0.1343 - val_loss: 0.2408 - val_accuracy: 0.7383 - val_dice_coef: 0.8608 - val_iou_seg: 0.2384
# Epoch 35/50
# 443/443 [==============================] - 38s 86ms/step - loss: 0.0739 - accuracy: 0.7540 - dice_coef: 0.9280 - iou_seg: 0.1328 - val_loss: 0.2192 - val_accuracy: 0.7392 - val_dice_coef: 0.8584 - val_iou_seg: 0.2419
# Epoch 36/50
# 443/443 [==============================] - 38s 85ms/step - loss: 0.0736 - accuracy: 0.7540 - dice_coef: 0.9283 - iou_seg: 0.1323 - val_loss: 0.2267 - val_accuracy: 0.7378 - val_dice_coef: 0.8616 - val_iou_seg: 0.2372
# Epoch 37/50
# 443/443 [==============================] - 38s 85ms/step - loss: 0.0723 - accuracy: 0.7542 - dice_coef: 0.9295 - iou_seg: 0.1303 - val_loss: 0.2179 - val_accuracy: 0.7393 - val_dice_coef: 0.8631 - val_iou_seg: 0.2354
# Epoch 38/50
# 443/443 [==============================] - 38s 85ms/step - loss: 0.0711 - accuracy: 0.7543 - dice_coef: 0.9308 - iou_seg: 0.1281 - val_loss: 0.2132 - val_accuracy: 0.7389 - val_dice_coef: 0.8583 - val_iou_seg: 0.2420
# Epoch 39/50
# 443/443 [==============================] - 36s 81ms/step - loss: 0.0714 - accuracy: 0.7543 - dice_coef: 0.9305 - iou_seg: 0.1286 - val_loss: 0.2127 - val_accuracy: 0.7391 - val_dice_coef: 0.8606 - val_iou_seg: 0.2390
# Epoch 40/50
# 443/443 [==============================] - 36s 81ms/step - loss: 0.0695 - accuracy: 0.7545 - dice_coef: 0.9325 - iou_seg: 0.1252 - val_loss: 0.2466 - val_accuracy: 0.7361 - val_dice_coef: 0.8585 - val_iou_seg: 0.2420
# Epoch 41/50
# 443/443 [==============================] - 38s 86ms/step - loss: 0.0685 - accuracy: 0.7546 - dice_coef: 0.9336 - iou_seg: 0.1233 - val_loss: 0.2291 - val_accuracy: 0.7324 - val_dice_coef: 0.8471 - val_iou_seg: 0.2593
# Epoch 42/50
# 443/443 [==============================] - 36s 82ms/step - loss: 0.0679 - accuracy: 0.7546 - dice_coef: 0.9341 - iou_seg: 0.1224 - val_loss: 0.2192 - val_accuracy: 0.7385 - val_dice_coef: 0.8599 - val_iou_seg: 0.2395
# Epoch 43/50
# 443/443 [==============================] - 38s 86ms/step - loss: 0.0696 - accuracy: 0.7543 - dice_coef: 0.9323 - iou_seg: 0.1255 - val_loss: 0.2337 - val_accuracy: 0.7374 - val_dice_coef: 0.8526 - val_iou_seg: 0.2505
# Epoch 44/50
# 443/443 [==============================] - 36s 81ms/step - loss: 0.0681 - accuracy: 0.7546 - dice_coef: 0.9340 - iou_seg: 0.1226 - val_loss: 0.2078 - val_accuracy: 0.7381 - val_dice_coef: 0.8577 - val_iou_seg: 0.2440
# Epoch 45/50
# 443/443 [==============================] - 38s 86ms/step - loss: 0.0758 - accuracy: 0.7530 - dice_coef: 0.9265 - iou_seg: 0.1349 - val_loss: 0.2069 - val_accuracy: 0.7379 - val_dice_coef: 0.8537 - val_iou_seg: 0.2492
# Epoch 46/50
# 443/443 [==============================] - 38s 86ms/step - loss: 0.0671 - accuracy: 0.7547 - dice_coef: 0.9349 - iou_seg: 0.1209 - val_loss: 0.2188 - val_accuracy: 0.7399 - val_dice_coef: 0.8657 - val_iou_seg: 0.2314
# Epoch 47/50
# 443/443 [==============================] - 38s 85ms/step - loss: 0.0629 - accuracy: 0.7551 - dice_coef: 0.9393 - iou_seg: 0.1134 - val_loss: 0.2215 - val_accuracy: 0.7399 - val_dice_coef: 0.8687 - val_iou_seg: 0.2270
# Epoch 48/50
# 443/443 [==============================] - 38s 85ms/step - loss: 0.0611 - accuracy: 0.7553 - dice_coef: 0.9410 - iou_seg: 0.1104 - val_loss: 0.2344 - val_accuracy: 0.7394 - val_dice_coef: 0.8669 - val_iou_seg: 0.2295
# Epoch 49/50
# 443/443 [==============================] - 38s 86ms/step - loss: 0.0605 - accuracy: 0.7553 - dice_coef: 0.9416 - iou_seg: 0.1093 - val_loss: 0.2462 - val_accuracy: 0.7389 - val_dice_coef: 0.8670 - val_iou_seg: 0.2291
# Epoch 50/50
# 443/443 [==============================] - 36s 82ms/step - loss: 0.0615 - accuracy: 0.7552 - dice_coef: 0.9405 - iou_seg: 0.1112 - val_loss: 0.2359 - val_accuracy: 0.7375 - val_dice_coef: 0.8635 - val_iou_seg: 0.2350

# %%
#Execution time of the model 
execution_time_att_unet = stop1-start1
print("att_unet execution time is: ", execution_time_att_unet)
# Out:
# att_unet execution time is:  0:31:28.956906

# %%
model_att_unet.save('attentionUnet.hdf5')

# %%
# convert the history.history dict to a pandas DataFrame and save as csv for
# future plotting
import pandas as pd    
att_unet_history_df = pd.DataFrame(att_unet_history.history) 

with open('att_unet_history_df.csv', mode='w') as f:
    att_unet_history_df.to_csv(f)

# %%
#Check history plots, one model at a time
history = att_unet_history

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.ylim(0, 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['dice_coef']
#acc = history.history['accuracy']
val_acc = history.history['val_dice_coef']
#val_acc = history.history['val_accuracy']

plt.ylim(0, 1)
plt.plot(epochs, acc, 'y', label='Training Dice')
plt.plot(epochs, val_acc, 'r', label='Validation Dice')
plt.title('Training and validation Dice')
plt.xlabel('Epochs')
plt.ylabel('Dice')
plt.legend()
plt.show()

# %%
model = model_att_unet

# %%
import random
test_img_number = random.randint(0, X_test.shape[0]-1)  #Test with 119

# %%
test_img = X_test[test_img_number]
ground_truth=y_test[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
prediction = (model.predict(test_img_input)[0,:,:,0] > 0.5).astype(np.uint8)
# Out:
# 1/1 [==============================] - 0s 454ms/step

# %%
plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img, cmap='gray')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth[:,:,0], cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(prediction, cmap='gray')

plt.show()

# %%
## Choose the number of examples to display
num_examples = 3

test_img = X_test[test_img_number]
ground_truth=y_test[test_img_number]
#test_img_norm=test_img[:,:,0][:,:,None]
test_img_input=np.expand_dims(test_img, 0)
prediction1 = (model.predict(test_img_input)[0,:,:,0] > 0.5).astype(np.uint8)


# Randomly select some indices for display
example_indices = [1,5,4]

# Display the selected examples
plt.figure(figsize=(15, 5 * num_examples))

for i, example_index in enumerate(example_indices, 1):
    test_img = X_test[example_index]
    test_img_input=np.expand_dims(test_img, 0)
    prediction1 = (model.predict(test_img_input)[0,:,:,0] > 0.5).astype(np.uint8)
    plt.subplot(num_examples, 3, 3 * i - 2)
    plt.imshow(X_test[example_index])
    plt.title(f"Image {example_index}")
    plt.axis('off')
    
    plt.subplot(num_examples, 3, 3 * i - 1)
    plt.imshow(y_test[example_index], cmap='gray')
    plt.title(f"Mask {example_index}")
    plt.axis('off')

    plt.subplot(num_examples, 3, 3 * i)
    plt.imshow(prediction1, cmap='gray')
    plt.title(f"Prediction {example_index}")
    plt.axis('off')

    
plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step

# %%
#IoU for a single image
from tensorflow.keras.metrics import MeanIoU
n_classes = 2
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(ground_truth[:,:,0], prediction)
print(" IoU =", IOU_keras.result().numpy())
# Out:
#  IoU = 0.6793703

# %%
import pandas as pd

IoU_values = []
for img in range(0, X_test.shape[0]):
    temp_img = X_test[img]
    ground_truth=y_test[img]
    temp_img_input=np.expand_dims(temp_img, 0)
    prediction = (model.predict(temp_img_input)[0,:,:,0] > 0.5).astype(np.uint8)
    
    IoU = MeanIoU(num_classes=n_classes)
    IoU.update_state(ground_truth[:,:,0], prediction)
    IoU = IoU.result().numpy()
    IoU_values.append(IoU)

    #print(IoU)
# Out:
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step

# %%
df = pd.DataFrame(IoU_values, columns=["IoU"])
df = df[df.IoU != 1.0]    
mean_IoU = df.mean().values
print("Mean IoU is: ", mean_IoU)
# Out:
# Mean IoU is:  [0.6913047]
